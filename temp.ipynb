# %%
import pandas as pd
import numpy as np
import os
from dotenv import load_dotenv

# %%
load_dotenv()
DATA_PATH = os.getenv("DATA_PATH")
csv = DATA_PATH + "/Account financiële data.csv"
df = pd.read_csv(csv, delimiter=",", encoding="utf-8", keep_default_na=True, na_values=[""], 
                    # decimal= ",", quotechar = '"', doublequote = True, dtype={"crm_FinancieleData_Toegevoegde_waarde": "Float64", "crm_FinancieleData_FTE": "Float64"}
                    )
df = df.replace({np.nan: None})

df["crm_FinancieleData_Gewijzigd_op"] = pd.to_datetime(df["crm_FinancieleData_Gewijzigd_op"], format="%d-%m-%Y %H:%M:%S")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2030217 entries, 0 to 2030216
# Data columns (total 6 columns):
#  #   Column                                 Dtype
# ---  ------                                 -----
#  0   crm_FinancieleData_OndernemingID       object
#  1   crm_FinancieleData_Boekjaar            int64
#  2   crm_FinancieleData_Aantal_maanden      object
#  3   crm_FinancieleData_Toegevoegde_waarde  object
#  4   crm_FinancieleData_FTE                 object
#  5   crm_FinancieleData_Gewijzigd_op        datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 92.9+ MB

# %%
df
# Out:
#              crm_FinancieleData_OndernemingID  crm_FinancieleData_Boekjaar  \
# 0        00002DAC-0A69-E111-B43A-00505680000A                         2007
# 1        00002DAC-0A69-E111-B43A-00505680000A                         2008
# 2        00002DAC-0A69-E111-B43A-00505680000A                         2009
# 3        00002DAC-0A69-E111-B43A-00505680000A                         2010
# 4        00002DAC-0A69-E111-B43A-00505680000A                         2011
# ...                                       ...                          ...
# 2030212  FFFF8DBC-B567-E111-A00F-00505680000A                         2005
# 2030213  FFFF8DBC-B567-E111-A00F-00505680000A                         2006
# 2030214  FFFF8DBC-B567-E111-A00F-00505680000A                         2007
# 2030215  FFFF8DBC-B567-E111-A00F-00505680000A                         2008
# 2030216  FFFF8DBC-B567-E111-A00F-00505680000A                         2009
#
#         crm_FinancieleData_Aantal_maanden  \
# 0                                    None
# 1                                    None
# 2                                    None
# 3                                    12.0
# 4                                    12.0
# ...                                   ...
# 2030212                              None
# 2030213                              None
# 2030214                              12.0
# 2030215                              12.0
# 2030216                              12.0
#
#         crm_FinancieleData_Toegevoegde_waarde crm_FinancieleData_FTE  \
# 0                                        None                      1
# 1                                        None                      1
# 2                                        None                      2
# 3                                        None                      1
# 4                                        None                      1
# ...                                       ...                    ...
# 2030212                                  None                    4,9
# 2030213                                  None                    5,1
# 2030214                                  None                      5
# 2030215                                  None                      6
# 2030216                                  None                      5
#
#         crm_FinancieleData_Gewijzigd_op
# 0                   2018-10-15 08:21:37
# 1                   2018-10-15 13:20:45
# 2                   2018-10-15 04:00:52
# 3                   2018-10-15 12:42:56
# 4                   2018-10-15 04:54:28
# ...                                 ...
# 2030212             2019-02-06 09:36:49
# 2030213             2019-02-06 09:55:07
# 2030214             2019-02-06 11:04:35
# 2030215             2019-02-06 11:41:26
# 2030216             2019-02-07 02:13:26
#
# [2030217 rows x 6 columns]

# %%
df['crm_FinancieleData_FTE'] = df['crm_FinancieleData_FTE'].str.replace(',', '.')
df['crm_FinancieleData_Toegevoegde_waarde'] = df['crm_FinancieleData_Toegevoegde_waarde'].str.replace(',', '.')
# df['crm_FinancieleData_Aantal_maanden'] = df['crm_FinancieleData_Aantal_maanden'].str.replace(',', '.')
df['crm_FinancieleData_FTE'] = pd.to_numeric(df['crm_FinancieleData_FTE'],errors='coerce')
df['crm_FinancieleData_Toegevoegde_waarde'] = pd.to_numeric(df['crm_FinancieleData_Toegevoegde_waarde'],errors='coerce')
# df['crm_FinancieleData_Aantal_maanden'] = pd.to_numeric(df['crm_FinancieleData_Aantal_maanden'],errors='coerce')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\rosie\Documents\Hogent\3de batch\sem1\DEP\DEP2-GROEP-1\temp.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/rosie/Documents/Hogent/3de%20batch/sem1/DEP/DEP2-GROEP-1/temp.ipynb#W2sZmlsZQ%3D%3D?line=0'>1</a> df['crm_FinancieleData_FTE'] = df['crm_FinancieleData_FTE'].str.replace(',', '.')
#       <a href='vscode-notebook-cell:/c%3A/Users/rosie/Documents/Hogent/3de%20batch/sem1/DEP/DEP2-GROEP-1/temp.ipynb#W2sZmlsZQ%3D%3D?line=1'>2</a> df['crm_FinancieleData_Aantal_maanden'] = df['crm_FinancieleData_Aantal_maanden'].str.replace(',', '.')
#       <a href='vscode-notebook-cell:/c%3A/Users/rosie/Documents/Hogent/3de%20batch/sem1/DEP/DEP2-GROEP-1/temp.ipynb#W2sZmlsZQ%3D%3D?line=2'>3</a> df['crm_FinancieleData_Toegevoegde_waarde'] = df['crm_FinancieleData_Toegevoegde_waarde'].str.replace(',', '.')
#
# File c:\Users\rosie\Documents\Hogent\3de batch\sem1\DEP\DEP2-GROEP-1\venv\Lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# File c:\Users\rosie\Documents\Hogent\3de batch\sem1\DEP\DEP2-GROEP-1\venv\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
#     225 # Replace the property with the accessor object. Inspired by:
#     226 # https://www.pydanny.com/cached-property.html
#     227 # We need to use object.__setattr__ because we overwrite __setattr__ on
#     228 # NDFrame
#     229 object.__setattr__(obj, self._name, accessor_obj)
#
# File c:\Users\rosie\Documents\Hogent\3de batch\sem1\DEP\DEP2-GROEP-1\venv\Lib\site-packages\pandas\core\strings\accessor.py:190, in StringMethods.__init__(self, data)
#     187 def __init__(self, data) -> None:
#     188     from pandas.core.arrays.string_ import StringDtype
# --> 190     self._inferred_dtype = self._validate(data)
#     191     self._is_categorical = isinstance(data.dtype, CategoricalDtype)
#     192     self._is_string = isinstance(data.dtype, StringDtype)
#
# File c:\Users\rosie\Documents\Hogent\3de batch\sem1\DEP\DEP2-GROEP-1\venv\Lib\site-packages\pandas\core\strings\accessor.py:244, in StringMethods._validate(data)
#     241 inferred_dtype = lib.infer_dtype(values, skipna=True)
#     243 if inferred_dtype not in allowed_types:
# --> 244     raise AttributeError("Can only use .str accessor with string values!")
#     245 return inferred_dtype
#
# AttributeError: Can only use .str accessor with string values!

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2030217 entries, 0 to 2030216
# Data columns (total 6 columns):
#  #   Column                                 Dtype
# ---  ------                                 -----
#  0   crm_FinancieleData_OndernemingID       object
#  1   crm_FinancieleData_Boekjaar            int64
#  2   crm_FinancieleData_Aantal_maanden      object
#  3   crm_FinancieleData_Toegevoegde_waarde  float64
#  4   crm_FinancieleData_FTE                 float64
#  5   crm_FinancieleData_Gewijzigd_op        datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), int64(1), object(2)
# memory usage: 92.9+ MB
#              crm_FinancieleData_OndernemingID  crm_FinancieleData_Boekjaar  \
# 0        00002DAC-0A69-E111-B43A-00505680000A                         2007
# 1        00002DAC-0A69-E111-B43A-00505680000A                         2008
# 2        00002DAC-0A69-E111-B43A-00505680000A                         2009
# 3        00002DAC-0A69-E111-B43A-00505680000A                         2010
# 4        00002DAC-0A69-E111-B43A-00505680000A                         2011
# ...                                       ...                          ...
# 2030212  FFFF8DBC-B567-E111-A00F-00505680000A                         2005
# 2030213  FFFF8DBC-B567-E111-A00F-00505680000A                         2006
# 2030214  FFFF8DBC-B567-E111-A00F-00505680000A                         2007
# 2030215  FFFF8DBC-B567-E111-A00F-00505680000A                         2008
# 2030216  FFFF8DBC-B567-E111-A00F-00505680000A                         2009
#
#         crm_FinancieleData_Aantal_maanden  \
# 0                                    None
# 1                                    None
# 2                                    None
# 3                                    12.0
# 4                                    12.0
# ...                                   ...
# 2030212                              None
# 2030213                              None
# 2030214                              12.0
# 2030215                              12.0
# 2030216                              12.0
#
#          crm_FinancieleData_Toegevoegde_waarde  crm_FinancieleData_FTE  \
# 0                                          NaN                     1.0
# 1                                          NaN                     1.0
# 2                                          NaN                     2.0
# 3                                          NaN                     1.0
# 4                                          NaN                     1.0
# ...                                        ...                     ...
# 2030212                                    NaN                     4.9
# 2030213                                    NaN                     5.1
# 2030214                                    NaN                     5.0
# 2030215                                    NaN                     6.0
# 2030216                                    NaN                     5.0
#
#         crm_FinancieleData_Gewijzigd_op
# 0                   2018-10-15 08:21:37
# 1                   2018-10-15 13:20:45
# 2                   2018-10-15 04:00:52
# 3                   2018-10-15 12:42:56
# 4                   2018-10-15 04:54:28
# ...                                 ...
# 2030212             2019-02-06 09:36:49
# 2030213             2019-02-06 09:55:07
# 2030214             2019-02-06 11:04:35
# 2030215             2019-02-06 11:41:26
# 2030216             2019-02-07 02:13:26
#
# [2030217 rows x 6 columns]
