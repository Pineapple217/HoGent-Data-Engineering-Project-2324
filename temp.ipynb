# %%
import pandas as pd

# %%
df = pd.read_csv('../Data/cdi_pageviews.csv',delimiter=";",encoding='utf-8', keep_default_na=True, na_values=[''])

# %%
df['crm CDI_PageView[Viewed On]'] = pd.to_datetime(df['crm CDI_PageView[Viewed On]'], format='%d/%m/%Y')
df['crm CDI_PageView[Time]'] = pd.to_datetime(df['crm CDI_PageView[Time]'], format='%m-%d-%Y %H:%M:%S (%Z)')
df['crm CDI_PageView[Aangemaakt op]]'] = pd.to_datetime(df['crm CDI_PageView[Aangemaakt op]'], format='%d/%m/%Y')
df['crm CDI_PageView[Gewijzigd op]]'] = pd.to_datetime(df['crm CDI_PageView[Gewijzigd op]'], format='%d/%m/%Y')

# %%
df.head()
# Out:
#    crm CDI_PageView[Anonymous Visitor] crm CDI_PageView[Browser]  \
# 0                                  NaN                   ANDROID
# 1                                  NaN                    CHROME
# 2                                  NaN                    CHROME
# 3                                  NaN                    CHROME
# 4                                  NaN                    CHROME
#
#   crm CDI_PageView[Campaign]             crm CDI_PageView[Contact]  \
# 0                        NaN  71C7CDFA-379C-EB11-811E-001DD8B72B62
# 1                        NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC
# 2                        NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC
# 3                        NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC
# 4                        NaN  2D1FD6B4-6575-ED11-81AB-6045BD895CDC
#
#    crm CDI_PageView[Duration] crm CDI_PageView[Operating System]  \
# 0                         NaN                              LINUX
# 1                         NaN                            WINDOWS
# 2                         3.0                            WINDOWS
# 3                         1.0                            WINDOWS
# 4                         NaN                            WINDOWS
#
#             crm CDI_PageView[Page View] crm CDI_PageView[Referrer Type]  \
# 0  44941A79-0980-461D-AEB7-20B9E49BBC73                   Search Engine
# 1  66BDB58C-045A-4916-960D-2B30EF276FF7                           Email
# 2  E7E1CCC4-20E6-4765-B99C-1E7CCA321B79                           Email
# 3  D3F9C81A-D70F-4F91-8141-0A9617DA433B                  Direct Traffic
# 4  AEA3FE35-46EE-4285-A4A4-37CECFEFDC49                           Email
#
#      crm CDI_PageView[Time]  \
# 0 2023-09-28 16:41:02+00:00
# 1 2023-09-28 16:28:37+00:00
# 2 2023-09-28 16:28:34+00:00
# 3 2023-09-28 16:28:33+00:00
# 4 2023-09-28 16:28:37+00:00
#
#                         crm CDI_PageView[Page Title]  ...  \
# 0                                 Voka Fietst | Voka  ...
# 1  Weer hogere loonindexering op komst in 2024 | ...  ...
# 2  Hoe zijn de nieuwste vooruitzichten voor onze ...  ...
# 3             West-Vlaanderen Ondernemers #13 | Voka  ...
# 4         Terug hogere loonindexering in 2024 | Voka  ...
#
#                 crm CDI_PageView[Visit]     crm CDI_PageView[Visitor Key]  \
# 0  F4E71546-14F4-4479-BB3E-C8B590ECCD75  cc6e75a300774c63a9d370db7b4783e8
# 1  C66FC6F4-4030-4357-8234-EC11D97717E8  c2024d5951e545638b651c8f4a10b764
# 2  C66FC6F4-4030-4357-8234-EC11D97717E8  c2024d5951e545638b651c8f4a10b764
# 3  C66FC6F4-4030-4357-8234-EC11D97717E8  c2024d5951e545638b651c8f4a10b764
# 4  C66FC6F4-4030-4357-8234-EC11D97717E8  c2024d5951e545638b651c8f4a10b764
#
#   crm CDI_PageView[Web Content] crm CDI_PageView[Aangemaakt op]  \
# 0                           NaN                      28/09/2023
# 1                           NaN                      28/09/2023
# 2                           NaN                      28/09/2023
# 3                           NaN                      28/09/2023
# 4                           NaN                      28/09/2023
#
#        crm CDI_PageView[Gewijzigd door] crm CDI_PageView[Gewijzigd op]  \
# 0  A30BACB8-C3A9-403D-9C1E-463FDD2C5AFC                     28/09/2023
# 1  A30BACB8-C3A9-403D-9C1E-463FDD2C5AFC                     28/09/2023
# 2  A30BACB8-C3A9-403D-9C1E-463FDD2C5AFC                     28/09/2023
# 3  7DEBF2A1-B543-EC11-8C62-000D3ABD69F9                     28/09/2023
# 4  A30BACB8-C3A9-403D-9C1E-463FDD2C5AFC                     28/09/2023
#
#   crm CDI_PageView[Status] crm CDI_PageView[Reden van status]  \
# 0                   Actief                             Actief
# 1                   Actief                             Actief
# 2                   Actief                             Actief
# 3                   Actief                             Actief
# 4                   Actief                             Actief
#
#   crm CDI_PageView[Aangemaakt op]] crm CDI_PageView[Gewijzigd op]]
# 0                       2023-09-28                      2023-09-28
# 1                       2023-09-28                      2023-09-28
# 2                       2023-09-28                      2023-09-28
# 3                       2023-09-28                      2023-09-28
# 4                       2023-09-28                      2023-09-28
#
# [5 rows x 23 columns]

# %%
df.columns.values
# Out:
# array(['crm CDI_PageView[Anonymous Visitor]', 'crm CDI_PageView[Browser]',
#        'crm CDI_PageView[Campaign]', 'crm CDI_PageView[Contact]',
#        'crm CDI_PageView[Duration]', 'crm CDI_PageView[Operating System]',
#        'crm CDI_PageView[Page View]', 'crm CDI_PageView[Referrer Type]',
#        'crm CDI_PageView[Time]', 'crm CDI_PageView[Page Title]',
#        'crm CDI_PageView[Type]', 'crm CDI_PageView[Url]',
#        'crm CDI_PageView[Viewed On]', 'crm CDI_PageView[Visit]',
#        'crm CDI_PageView[Visitor Key]', 'crm CDI_PageView[Web Content]',
#        'crm CDI_PageView[Aangemaakt op]',
#        'crm CDI_PageView[Gewijzigd door]',
#        'crm CDI_PageView[Gewijzigd op]', 'crm CDI_PageView[Status]',
#        'crm CDI_PageView[Reden van status]'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   crm CDI_PageView[Anonymous Visitor]  0 non-null       float64
#  1   crm CDI_PageView[Browser]            499829 non-null  object
#  2   crm CDI_PageView[Campaign]           23359 non-null   object
#  3   crm CDI_PageView[Contact]            500000 non-null  object
#  4   crm CDI_PageView[Duration]           354111 non-null  float64
#  5   crm CDI_PageView[Operating System]   500000 non-null  object
#  6   crm CDI_PageView[Page View]          500000 non-null  object
#  7   crm CDI_PageView[Referrer Type]      500000 non-null  object
#  8   crm CDI_PageView[Time]               500000 non-null  object
#  9   crm CDI_PageView[Page Title]         494290 non-null  object
#  10  crm CDI_PageView[Type]               500000 non-null  object
#  11  crm CDI_PageView[Url]                500000 non-null  object
#  12  crm CDI_PageView[Viewed On]          500000 non-null  object
#  13  crm CDI_PageView[Visit]              499895 non-null  object
#  14  crm CDI_PageView[Visitor Key]        500000 non-null  object
#  15  crm CDI_PageView[Web Content]        6195 non-null    object
#  16  crm CDI_PageView[Aangemaakt op]      500000 non-null  object
#  17  crm CDI_PageView[Gewijzigd door]     500000 non-null  object
#  18  crm CDI_PageView[Gewijzigd op]       500000 non-null  object
#  19  crm CDI_PageView[Status]             500000 non-null  object
#  20  crm CDI_PageView[Reden van status]   500000 non-null  object
# dtypes: float64(2), object(19)
# memory usage: 80.1+ MB

# %%
df = df.where(pd.notna(df), None)

# %%
df['crm CDI_PageView[Browser]'][16877]
